# %% [markdown]
# # Python for data analysis and visualisation
#
# ## Online short course at the University of St Andrews
#
# ## Final assignment
#
# ### [Ryan Stuart]

# %%
import pandas as pd

# %% [markdown]
# We start with exploring the content of the dataset.

# %%
df = pd.read_csv("../data/Scotland_teaching_file_1PCT.csv")

# %%
df
# Out:
#        Record_Number     Region RESIDENCE_TYPE Family_Composition  sex  age  \
# 0                  1  S92000003              P                  1    1    4
# 1                  2  S92000003              P                  0    1    3
# 2                  3  S92000003              P                  1    2    4
# 3                  4  S92000003              P                  1    2    6
# 4                  5  S92000003              P                  4    2    4
# ...              ...        ...            ...                ...  ...  ...
# 63383          63384  S92000003              P                  1    1    2
# 63384          63385  S92000003              P                  1    1    4
# 63385          63386  S92000003              P                  1    1    5
# 63386          63387  S92000003              P                  4    2    1
# 63387          63388  S92000003              P                  1    1    5
#
#        Marital_Status  student  Country_Of_Birth  health  Ethnic_Group  \
# 0                   2        2                 2       2             1
# 1                   1        2                 1       2             1
# 2                   2        2                 1       3             1
# 3                   2        2                 1       1             1
# 4                   4        2                 1       2             1
# ...               ...      ...               ...     ...           ...
# 63383               1        1                 1       1             1
# 63384               2        2                 1       1             1
# 63385               2        2                 1       1             1
# 63386               1        1                 1       1             1
# 63387               2        2                 1       2             1
#
#        religion Economic_Activity Occupation industry Hours_Worked_Per_Week  \
# 0             5                 1          5        5                     4
# 1             1                 1          1        8                     3
# 2             1                 1          4        8                     2
# 3             1                 1          2        8                     4
# 4             1                 1          3       11                     3
# ...         ...               ...        ...      ...                   ...
# 63383         2                 6          X        X                     X
# 63384         1                 1          3        9                     3
# 63385         9                 1          8        3                     4
# 63386         9                 X          X        X                     X
# 63387         2                 2          8        2                     4
#
#       Approximate_Social_Grade
# 0                            3
# 1                            2
# 2                            4
# 3                            2
# 4                            2
# ...                        ...
# 63383                        3
# 63384                        2
# 63385                        4
# 63386                        X
# 63387                        4
#
# [63388 rows x 17 columns]

# %%
print(df["RESIDENCE_TYPE"].value_counts())
print(df["Family_Composition"].value_counts())
print(df["sex"].value_counts())
print(df["age"].value_counts())
print(df["Marital_Status"].value_counts())
print(df["student"].value_counts())
print(df["Country_Of_Birth"].value_counts())
print(df["health"].value_counts())
print(df["Ethnic_Group"].value_counts())
print(df["religion"].value_counts())
print(df["Economic_Activity"].value_counts())
print(df["Occupation"].value_counts())
print(df["industry"].value_counts())
print(df["Hours_Worked_Per_Week"].value_counts())
print(df["Approximate_Social_Grade"].value_counts())
# Out:
# RESIDENCE_TYPE
# P    62239
# C     1149
# Name: count, dtype: int64
# Family_Composition
# 1    33337
# 0    11716
# 4     7757
# 2     7660
# X     1149
# 3     1019
# 5      750
# Name: count, dtype: int64
# sex
# 2    32696
# 1    30692
# Name: count, dtype: int64
# age
# 1    10980
# 5     9336
# 4     8963
# 3     8056
# 6     7854
# 2     7541
# 7     5731
# 8     4927
# Name: count, dtype: int64
# Marital_Status
# 1    29611
# 2    23918
# 4     4159
# 5     4032
# 3     1668
# Name: count, dtype: int64
# student
# 2    51397
# 1    11991
# Name: count, dtype: int64
# Country_Of_Birth
# 1    59045
# 2     4343
# Name: count, dtype: int64
# health
# 1    33436
# 2    18825
# 3     7544
# 4     2759
# 5      824
# Name: count, dtype: int64
# Ethnic_Group
# 1    60901
# 3     1667
# 4      376
# 2      199
# 6      165
# 5       80
# Name: count, dtype: int64
# religion
# 2    34199
# 1    23309
# 9     4335
# 6      906
# 4      187
# 8      162
# 7      116
# 3      113
# 5       61
# Name: count, dtype: int64
# Economic_Activity
# 1    25350
# 5    11527
# X    10980
# 2     3623
# 6     2691
# 8     2543
# 3     2183
# 4     1743
# 7     1741
# 9     1007
# Name: count, dtype: int64
# Occupation
# X    14435
# 9     7256
# 2     7237
# 5     6140
# 4     6010
# 3     5015
# 7     4934
# 6     4484
# 8     4327
# 1     3550
# Name: count, dtype: int64
# industry
# X     14435
# 4      7557
# 11     6817
# 2      6318
# 8      4818
# 10     4123
# 3      3876
# 6      3754
# 5      3309
# 9      3225
# 7      1979
# 13     1172
# 12     1107
# 1       898
# Name: count, dtype: int64
# Hours_Worked_Per_Week
# X    32851
# 3    18333
# 2     6518
# 4     3543
# 1     2143
# Name: count, dtype: int64
# Approximate_Social_Grade
# 2    15607
# 4    14709
# X    12090
# 3    11602
# 1     9380
# Name: count, dtype: int64

# %% [markdown]
# ### perform the descriptive analysis of the dataset:
#
# - the total number of records in the refined dataset are: 28552
# - All the different values for each variable and their occurence in the refined dataset are:
#
# `RESIDENCE_TYPE:`
# **P:**    27999
# **C:**      553
#
# `Family_Composition:`
# **1:**    14910
# **4:**     4997
# **0:**     3953
# **2:**     3402
# **X:**      553
# **3:**      425
# **5:**      312
#
# `sex:`
# **2:**    17524
# **1:**    11028
#
# `age:`
# **1:**    10980
# **2:**     3197
# **5:**     3112
# **4:**     2782
# **6:**     2618
# **3:**     2415
# **7:**     1850
# **8:**     1598
#
# `Marital_Status:`
# **1:**    17654
# **2:**     7530
# **5:**     1479
# **4:**     1345
# **3:**      544
#
# `student:`
# **2:**    18587
# **1:**     9965
#
# `Country_Of_Birth:`
# **1:**    26612
# **2:**    1940
#
# `health:`
# **1:**    17596
# **2:**     7076
# **3:**     2648
# **4:**     944
# **5:**      288
#
# `Ethnic_Group:`
# **1:**    27088
# **3:**      935
# **4:**      228
# **2:**      144
# **6:**      105
# **5:**       52
#
# `religion:`
# **2:**    14599
# **1:**    11068
# **9:**     2037
# **6:**      546
# **4:**      107
# **8:**       72
# **3:**       56
# **7:**       43
# **5:**       24
#
# `Economic_Activity:`
# **X:**    10980
# **1:**     7628
# **5:**     3731
# **6:**     1840
# **2:**     1047
# **8:**     1010
# **7:**      716
# **3:**      655
# **4:**      523
# **9:**      422
#
# `Occupation:`
# **X:**    14435
# **2:**     4412
# **6:**     3766
# **9:**     1585
# **4:**     1432
# **3:**    1227
# **5:**      775
# **1:**      543
# **8:**      243
# **7:**      134
#
# `industry:`
# **X:**     14435
# **11:**     6817
# **10:**     4123
# **13:**     1172
# **12:**     1107
# **1:**       898
#
# `Hours_Worked_Per_Week:`
# **X:**    19533
# **3:**     4875
# **2:**    2636
# **4:**      812
# **1:**      696
#
# `Approximate_Social_Grade:`
# **X:**    11494
# **2:**     4942
# **4:**     4848
# **1:**     3976

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/Refined_Scotland_teaching_file_1PCT.csv')

# %%
df
# Out:
#        Record_Number     Region RESIDENCE_TYPE Family_Composition  sex  age  \
# 0                  5  S92000003              P                  4    2    4
# 1                  8  S92000003              P                  2    2    1
# 2                  9  S92000003              P                  1    2    1
# 3                 12  S92000003              P                  1    2    1
# 4                 20  S92000003              P                  4    2    1
# ...              ...        ...            ...                ...  ...  ...
# 28547          63379  S92000003              P                  1    1    1
# 28548          63380  S92000003              P                  1    2    1
# 28549          63382  S92000003              P                  1    2    1
# 28550          63384  S92000003              P                  1    1    2
# 28551          63387  S92000003              P                  4    2    1
#
#        Marital_Status  student  Country_Of_Birth  health  Ethnic_Group  \
# 0                   4        2                 1       2             1
# 1                   1        1                 1       2             1
# 2                   1        1                 1       1             1
# 3                   1        2                 1       1             1
# 4                   1        1                 1       1             1
# ...               ...      ...               ...     ...           ...
# 28547               1        1                 1       1             1
# 28548               1        1                 1       1             1
# 28549               1        1                 1       1             1
# 28550               1        1                 1       1             1
# 28551               1        1                 1       1             1
#
#        religion Economic_Activity Occupation industry Hours_Worked_Per_Week  \
# 0             1                 1          3       11                     3
# 1             1                 X          X        X                     X
# 2             1                 X          X        X                     X
# 3             1                 X          X        X                     X
# 4             1                 X          X        X                     X
# ...         ...               ...        ...      ...                   ...
# 28547         1                 X          X        X                     X
# 28548         1                 X          X        X                     X
# 28549         1                 X          X        X                     X
# 28550         2                 6          X        X                     X
# 28551         9                 X          X        X                     X
#
#       Approximate_Social_Grade
# 0                            2
# 1                            X
# 2                            X
# 3                            X
# 4                            X
# ...                        ...
# 28547                        X
# 28548                        X
# 28549                        X
# 28550                        3
# 28551                        X
#
# [28552 rows x 17 columns]

# %%
df["Record_Number"].value_counts()
# Out:
# Record_Number
# 5        1
# 42522    1
# 42544    1
# 42543    1
# 42542    1
#         ..
# 21264    1
# 21262    1
# 21261    1
# 21260    1
# 63387    1
# Name: count, Length: 28552, dtype: int64

# %%
print(df["RESIDENCE_TYPE"].value_counts())
print(df["Family_Composition"].value_counts())
print(df["sex"].value_counts())
print(df["age"].value_counts())
print(df["Marital_Status"].value_counts())
print(df["student"].value_counts())
print(df["Country_Of_Birth"].value_counts())
print(df["health"].value_counts())
print(df["Ethnic_Group"].value_counts())
print(df["religion"].value_counts())
print(df["Economic_Activity"].value_counts())
print(df["Occupation"].value_counts())
print(df["industry"].value_counts())
print(df["Hours_Worked_Per_Week"].value_counts())
print(df["Approximate_Social_Grade"].value_counts())
# Out:
# RESIDENCE_TYPE
# P    27999
# C      553
# Name: count, dtype: int64
# Family_Composition
# 1    14910
# 4     4997
# 0     3953
# 2     3402
# X      553
# 3      425
# 5      312
# Name: count, dtype: int64
# sex
# 2    17524
# 1    11028
# Name: count, dtype: int64
# age
# 1    10980
# 2     3197
# 5     3112
# 4     2782
# 6     2618
# 3     2415
# 7     1850
# 8     1598
# Name: count, dtype: int64
# Marital_Status
# 1    17654
# 2     7530
# 5     1479
# 4     1345
# 3      544
# Name: count, dtype: int64
# student
# 2    18587
# 1     9965
# Name: count, dtype: int64
# Country_Of_Birth
# 1    26612
# 2     1940
# Name: count, dtype: int64
# health
# 1    17596
# 2     7076
# 3     2648
# 4      944
# 5      288
# Name: count, dtype: int64
# Ethnic_Group
# 1    27088
# 3      935
# 4      228
# 2      144
# 6      105
# 5       52
# Name: count, dtype: int64
# religion
# 2    14599
# 1    11068
# 9     2037
# 6      546
# 4      107
# 8       72
# 3       56
# 7       43
# 5       24
# Name: count, dtype: int64
# Economic_Activity
# X    10980
# 1     7628
# 5     3731
# 6     1840
# 2     1047
# 8     1010
# 7      716
# 3      655
# 4      523
# 9      422
# Name: count, dtype: int64
# Occupation
# X    14435
# 2     4412
# 6     3766
# 9     1585
# 4     1432
# 3     1227
# 5      775
# 1      543
# 8      243
# 7      134
# Name: count, dtype: int64
# industry
# X     14435
# 11     6817
# 10     4123
# 13     1172
# 12     1107
# 1       898
# Name: count, dtype: int64
# Hours_Worked_Per_Week
# X    19533
# 3     4875
# 2     2636
# 4      812
# 1      696
# Name: count, dtype: int64
# Approximate_Social_Grade
# X    11494
# 2     4942
# 4     4848
# 1     3976
# 3     3292
# Name: count, dtype: int64

# %%
print(df.dtypes)
# Out:
# Record_Number                int64
# Region                      object
# RESIDENCE_TYPE              object
# Family_Composition          object
# sex                          int64
# age                          int64
# Marital_Status               int64
# student                      int64
# Country_Of_Birth             int64
# health                       int64
# Ethnic_Group                 int64
# religion                     int64
# Economic_Activity           object
# Occupation                  object
# industry                    object
# Hours_Worked_Per_Week       object
# Approximate_Social_Grade    object
# dtype: object

# %% [markdown]
# ## build the following plots:
# – bar chart for the number of records for each age group
#
# – bar chart for the number of records for each occupation

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('../data/Refined_Scotland_teaching_file_1PCT.csv')
df = pd.DataFrame(data)

with plt.style.context('dark_background'):
    df['age'].value_counts().plot(kind='bar')
plt.xlabel('age')
plt.ylabel('Number of records')
plt.title('Number of records in each age group: census 2011')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('../data/Refined_Scotland_teaching_file_1PCT.csv')
df = pd.DataFrame(data)

with plt.style.context('dark_background'):
    df['Occupation'].value_counts().plot(kind='bar')
plt.xlabel('Occupation')
plt.ylabel('Number of records')
plt.title('Number of records in each occupation: census 2011')
plt.show()
